# %%
import pandas as pd

# %%
data=pd.read_csv("50_Startups.csv")

# %%
data
# Out:
#        Spends      Unnamed: 1       Unnamed: 2  Unnamed: 3 Unnamed: 4
# 0   R&D Spend  Administration  Marketing Spend       State     Profit
# 1    165349.2        136897.8         471784.1    New York  192261.83
# 2    162597.7       151377.59        443898.53  California  191792.06
# 3   153441.51       101145.55        407934.54     Florida  191050.39
# 4   144372.41       118671.85        383199.62    New York  182901.99
# 5   142107.34        91391.77        366168.42     Florida  166187.94
# 6    131876.9        99814.71        362861.36    New York  156991.12
# 7   134615.46       147198.87        127716.82  California  156122.51
# 8   130298.13       145530.06        323876.68     Florida   155752.6
# 9   120542.52       148718.95        311613.29    New York  152211.77
# 10  123334.88       108679.17        304981.62  California  149759.96
# 11  101913.08       110594.11        229160.95     Florida  146121.95
# ...

# %%
data['State'][data['Profit']==data['Profit'].max()]
# Out:
# 0    New York
# Name: State, dtype: object

# %%
data['State'][data['Administration']==data['Administration'].min()]
# Out:
# 37    California
# Name: State, dtype: object

# %%
data['Administration'].min()
# Out:
# 51283.14

# %%
# To see number of rows and column
data.shape
# Out:
# (50, 5)

# %%
type(data.shape)
# Out:
# tuple

# %%
# Shape is in tuple format So 
rows, columns=data.shape

print(rows)
print(columns)
# Out:
# 50
# 5

# %%
# TO print first 5 rows
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# TO print first specified number of rows
data.head(2)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.2       136897.80        471784.10    New York  192261.83
# 1   162597.7       151377.59        443898.53  California  191792.06

# %%
# TO print tail 5 rows
data.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
# TO print last specified number of rows
data.tail(2)
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
# indexing

data[7:11]
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95

# %%
# Columns

data.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
# to print individual column

data.State
# Out:
# 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# Name: State, dtype: object

# %%
data['State'] # data.State both are same
# Out:
# 0       New York
# 1     California
# 2        Florida
# 3       New York
# 4        Florida
# 5       New York
# 6     California
# 7        Florida
# 8       New York
# 9     California
# 10       Florida
# 11    California
# 12       Florida
# 13    California
# 14       Florida
# 15      New York
# 16    California
# 17      New York
# 18       Florida
# 19      New York
# 20    California
# 21      New York
# 22       Florida
# 23       Florida
# 24      New York
# 25    California
# 26       Florida
# 27      New York
# 28       Florida
# 29      New York
# 30       Florida
# 31      New York
# 32    California
# 33       Florida
# 34    California
# 35      New York
# 36       Florida
# 37    California
# 38      New York
# 39    California
# 40    California
# 41       Florida
# 42    California
# 43      New York
# 44    California
# 45      New York
# 46       Florida
# 47    California
# 48      New York
# 49    California
# Name: State, dtype: object

# %%
# To print specific columns

data[['Administration','State']]
# Out:
#     Administration       State
# 0        136897.80    New York
# 1        151377.59  California
# 2        101145.55     Florida
# 3        118671.85    New York
# 4         91391.77     Florida
# 5         99814.71    New York
# 6        147198.87  California
# 7        145530.06     Florida
# 8        148718.95    New York
# 9        108679.17  California
# 10       110594.11     Florida
# 11        91790.61  California
# 12       127320.38     Florida
# 13       135495.07  California
# 14       156547.42     Florida
# 15       122616.84    New York
# 16       121597.55  California
# 17       145077.58    New York
# 18       114175.79     Florida
# 19       153514.11    New York
# 20       113867.30  California
# 21       153773.43    New York
# 22       122782.75     Florida
# 23       105751.03     Florida
# 24        99281.34    New York
# 25       139553.16  California
# 26       144135.98     Florida
# 27       127864.55    New York
# 28       182645.56     Florida
# ...

# %%
# Maximum, minimum value from the column 
data['Administration'].max()
# Out:
# 182645.56

# %%
data['Administration'].min()
# Out:
# 51283.14

# %%
# Statistic of data

data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
# Operations on data

data[data.Administration>=150000]
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 1   162597.70       151377.59        443898.53  California  191792.06
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 19   86419.70       153514.11             0.00    New York  122776.86
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 34   46426.07       157693.92        210797.67  California   96712.80
# 44   22177.74       154806.14         28334.72  California   65200.33

# %%
# maximum of Administration
data[data.Administration==data.Administration.max()]
# Out:
#     R&D Spend  Administration  Marketing Spend    State     Profit
# 28   66051.52       182645.56         118148.2  Florida  103282.38

# %%
data[['State','Profit']][data.Profit==data.Profit.min()]
# Out:
#          State   Profit
# 49  California  14681.4

# %%
data[(data.Profit>=150000) & (data.Administration>=15000)]
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77

# %%
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# setting index as Administration, inplace=True is used to reflect original data
data.set_index('Administration',inplace=True)

# %%
data
# Out:
#                 R&D Spend  Marketing Spend       State     Profit
# Administration
# 136897.80       165349.20        471784.10    New York  192261.83
# 151377.59       162597.70        443898.53  California  191792.06
# 101145.55       153441.51        407934.54     Florida  191050.39
# 118671.85       144372.41        383199.62    New York  182901.99
# 91391.77        142107.34        366168.42     Florida  166187.94
# 99814.71        131876.90        362861.36    New York  156991.12
# 147198.87       134615.46        127716.82  California  156122.51
# 145530.06       130298.13        323876.68     Florida  155752.60
# 148718.95       120542.52        311613.29    New York  152211.77
# 108679.17       123334.88        304981.62  California  149759.96
# 110594.11       101913.08        229160.95     Florida  146121.95
# 91790.61        100671.96        249744.55  California  144259.40
# 127320.38        93863.75        249839.44     Florida  141585.52
# ...

# %%
# check row using index value

data.loc[108679.17]
# Out:
# R&D Spend              123335
# Marketing Spend        304982
# State              California
# Profit                 149760
# Name: 108679.17, dtype: object

# %%
# resetting index

data.reset_index(inplace=True)

# %%
data
# Out:
#     Administration  R&D Spend  Marketing Spend       State     Profit
# 0        136897.80  165349.20        471784.10    New York  192261.83
# 1        151377.59  162597.70        443898.53  California  191792.06
# 2        101145.55  153441.51        407934.54     Florida  191050.39
# 3        118671.85  144372.41        383199.62    New York  182901.99
# 4         91391.77  142107.34        366168.42     Florida  166187.94
# 5         99814.71  131876.90        362861.36    New York  156991.12
# 6        147198.87  134615.46        127716.82  California  156122.51
# 7        145530.06  130298.13        323876.68     Florida  155752.60
# 8        148718.95  120542.52        311613.29    New York  152211.77
# 9        108679.17  123334.88        304981.62  California  149759.96
# 10       110594.11  101913.08        229160.95     Florida  146121.95
# 11        91790.61  100671.96        249744.55  California  144259.40
# ...
